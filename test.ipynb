# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # I-Exploration des données

# %% [markdown]
# ##   1-concaténation des deux dataset

# %% [markdown]
# nos jeu de données initial contient 2 fichiers **test.csv** et **train.csv** ,le premièr travaille consiste à les concaténer

# %%
# Load the train and test datasets
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# Concatenate the datasets
dataSet = pd.concat([train_df, test_df], ignore_index=True)

dataSet.head()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_5672\2755473492.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# ...

# %%
dataSet.count()
# Out:
# ID                          150000
# Customer_ID                 150000
# Month                       150000
# Name                        135000
# Age                         150000
# SSN                         150000
# Occupation                  150000
# Annual_Income               150000
# Monthly_Inhand_Salary       127500
# Num_Bank_Accounts           150000
# Num_Credit_Card             150000
# Interest_Rate               150000
# Num_of_Loan                 150000
# Type_of_Loan                132888
# Delay_from_due_date         150000
# Num_of_Delayed_Payment      139500
# Changed_Credit_Limit        150000
# Num_Credit_Inquiries        147000
# Credit_Mix                  150000
# Outstanding_Debt            150000
# Credit_Utilization_Ratio    150000
# Credit_History_Age          136500
# Payment_of_Min_Amount       150000
# Total_EMI_per_month         150000
# Amount_invested_monthly     143250
# Payment_Behaviour           150000
# Monthly_Balance             148238
# ...

# %%
dataSet.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count          127500.000000      150000.000000    150000.000000
# mean             4190.115139          17.006940        22.623447
# std              3180.489657         117.069476       129.143006
# min               303.645417          -1.000000         0.000000
# 25%              1625.265833           3.000000         4.000000
# 50%              3091.000000           6.000000         5.000000
# 75%              5948.454596           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  150000.000000        150000.000000         147000.000000
# mean       71.234907            21.063400             28.529014
# std       461.537193            14.860154            194.456058
# min         1.000000            -5.000000              0.000000
# ...
